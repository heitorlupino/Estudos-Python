# %%
meta = 20000
vendas = 25000

if(vendas < meta):
    print('Não ganhou bonus')
elif(vendas > (meta * 2)):
    bonus = 0.07 * vendas
    print(f'Ganhou {bonus} bonus')
else:
    bonus = 0.03 * vendas
    print(f'Ganhou {bonus} de bonus')
# Out:
# Ganhou 2870.0000000000005 bonus
